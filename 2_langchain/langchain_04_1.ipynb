# %% [markdown]
# ### LMstudio 사용

# %% [markdown]
# ### langchain 사용

# %%
# from langchain.chat_models import ChatOpenAI
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import ChatPromptTemplate

# LM Studio 모델을 불러옵니다.
llm = ChatOpenAI(
    openai_api_base="http://localhost:12345/v1",
    openai_api_key="lm-studio",  # 아무 문자열이나 가능 (LM Studio는 키 검사 안 함)
    model_name="gemma-3-1b-it",        # LM Studio에서 사용 중인 모델 이름
    temperature=0.7,
)

# 프롬프트
prompt = ChatPromptTemplate.from_template("{topic} 에 대하여 간략히 설명해 줘.")

# 체인 생성
chain = prompt | llm | StrOutputParser()

# 간결성을 위해 응답은 터미널에 출력됩니다.
answer = chain.invoke({"topic": "대한민국의 인구"})

print(answer)
# Out:
# ## 대한민국 인구 현황 (2024년 5월 기준)
#
# 대한민국은 세계적으로도 높은 인구를 가진 나라 중 하나입니다. 2023년 11월 1일 기준 인구는 **14억 287백만 명**으로, 세계에서 12위권에 속합니다.
#
# **인구 구성:**
#
# *   **남성:** 약 5억 6천만 명 (약 60%)
# *   **여성:** 약 9억 2천만 명 (약 40%)
# *   **나이 순위:**  10대 후반부터 60대 초반까지 매우 젊은 인구 비율이 높습니다.
#
# **인구 분포:**
#
# *   **수도권:** 서울, 경기, 인천 등 수도권 지역에 집중되어 있습니다.
# *   **지역별 분포:**  강원도, 충청북도, 경상북도 등 남부 지역은 인구가 밀집되어 있습니다.
# *   **지방:** 지방 소도시 및 농어촌 지역이 비율을 차지합니다.
#
# **인구 변화 추세:**
#
# *   **출산율 감소:** 20여 년간 출산율이 지속적으로 감소하고 있어, 인구 증가 속도가 느려지고 있습니다.
# *   **고령화 심화:**  65세 이상 고령 인구가 비율이 높아지면서 사회 유지 및 경제적 부담이 증가할 것으로 예상됩니다.
#
# **참고 자료:**
#
# *   **통계청:** [https://kostat.go.kr/](https://kostat.go.kr/)
# *   **인구사회연구원:** [https://www.korea-social.org/](https://www.korea-social.org/)
#
# 더 자세한 정보는 통계청 또는 인구사회연구원의 자료를 참고하시면 좋습니다.
