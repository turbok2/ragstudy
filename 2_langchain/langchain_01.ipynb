# %%
from dotenv import load_dotenv
# API KEY 정보 불러오기
load_dotenv()
# Out:
# True

# %%
from langchain.llms import OpenAI
llm = OpenAI(temperature=0.9)
prompt = "Langchain이란 무엇인가?"
print(llm(prompt))
# Out:
# C:\Users\turbo\AppData\Local\Temp\ipykernel_28872\1771357266.py:2: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   llm = OpenAI(temperature=0.9)
# C:\Users\turbo\AppData\Local\Temp\ipykernel_28872\1771357266.py:4: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use invoke instead.
#   print(llm(prompt))
# Langchain은 다양한 프로그래밍 언어를 하나의 체인에 통합하여 사용할 수 있는 분산 컴퓨팅 플랫폼입니다. 이는 블록체인 기술을 활용하여 다양한 개발 언어들을 연결하고 상호 운용성을 제공하는 것을 목표로 합니다. 이를 통해 다른 블록체인 프로젝트들과의 연계성을 높이고 개발자들이 자유롭게 원하는 언어를 사용하여 블록체인 애플리케이션을 개발할 수 있게 됩니다.
