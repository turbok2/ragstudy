# %%
from dotenv import load_dotenv
# API KEY 정보 불러오기
load_dotenv()
# Out:
# True

# %%
from langchain.llms import OpenAI
llm = OpenAI(temperature=0.9)
prompt = "Langchain이란 무엇인가?"
print(llm(prompt))
# Out:
# C:\Users\turbo\AppData\Local\Temp\ipykernel_22620\1771357266.py:2: LangChainDeprecationWarning: The class `OpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   llm = OpenAI(temperature=0.9)
# C:\Users\turbo\AppData\Local\Temp\ipykernel_22620\1771357266.py:4: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use invoke instead.
#   print(llm(prompt))
# Langchain은 블록체인 기술을 기반으로 구축된 언어 교육 플랫폼입니다. 이 플랫폼은 언어 교육 시장의 문제점을 해결하고 학습자들이 보다 효율적이고 개인화된 학습 경험을 할 수 있도록 돕습니다.
#
# Langchain은 언어 교육을 위해 전 세계 언어 학교와 협력하며, 블록체인 기술을 사용하여 학습자들의 학습 데이터를 안전하게 저장하고 관리합니다. 또한 스마트 컨트랙트를 활용하여 학습 성과에 따른 보상을 제공하고, 학습자들 간에 언어 교환을 통해 실제 사용할 수 있는 학습 환경을 제공합니다.
#
# Langchain의
