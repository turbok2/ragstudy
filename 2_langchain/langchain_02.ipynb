# %%
from dotenv import load_dotenv
# API KEY 정보 불러오기
load_dotenv()
# Out:
# True

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser

# %%
# 프롬프트
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "당신은 친절한 AI 어시스턴트입니다"),
        ("user", "#Question:\n{question}"),
    ]
)
# 모델
llm = ChatOpenAI(model_name="gpt-4o", temperature=0)
# 출력파서
output_parser = StrOutputParser()

# 체인생성
chain = prompt | llm | output_parser

# %%
user_input = "대한민국의 주요 관광지를 알려줘"

# %%
response = chain.invoke({"question": user_input})
print(response)
# Out:
# 대한민국에는 다양한 매력적인 관광지가 많이 있습니다. 다음은 그 중 일부를 소개합니다:
#
# 1. **서울**
#    - **경복궁**: 조선 시대의 대표적인 궁궐로, 한국의 역사와 문화를 체험할 수 있는 곳입니다.
#    - **남산타워(N서울타워)**: 서울의 전경을 한눈에 볼 수 있는 전망대입니다.
#    - **명동**: 쇼핑과 맛집이 많은 번화가로, 관광객들에게 인기가 많습니다.
#    - **인사동**: 전통 공예품과 예술 작품을 구경할 수 있는 문화 거리입니다.
#
# 2. **부산**
#    - **해운대 해수욕장**: 대한민국을 대표하는 해수욕장으로, 여름철 많은 관광객이 찾습니다.
#    - **광안리 해수욕장**: 광안대교의 야경이 아름다운 해변입니다.
#    - **자갈치 시장**: 신선한 해산물을 맛볼 수 있는 전통 시장입니다.
#
# 3. **경주**
#    - **불국사**: 유네스코 세계문화유산으로 지정된 사찰로, 아름다운 건축물과 자연 경관을 자랑합니다.
#    - **석굴암**: 불국사와 함께 유네스코 세계문화유산으로 지정된 석굴 사원입니다.
#    - **첨성대**: 동양에서 가장 오래된 천문대입니다.
#
# 4. **제주도**
#    - **한라산**: 대한민국에서 가장 높은 산으로, 다양한 등산 코스와 아름다운 자연 경관을 즐길 수 있습니다.
#    - **성산일출봉**: 일출을 감상하기 좋은 명소로, 유네스코 세계자연유산으로 지정되었습니다.
#    - **천지연 폭포**: 아름다운 폭포와 주변 자연 경관이 인상적인 곳입니다.
#
# 5. **전주**
#    - **전주 한옥마을**: 전통 한옥이 모여 있는 마을로, 한국의 전통 문화를 체험할 수 있습니다.
#    - **전주 비빔밥**: 전주의 대표적인 음식으로, 다양한 재료가 어우러진 맛을 즐길 수 있습니다.
#
# 6. **강릉**
#    - **경포대**: 아름다운 해변과 호수가 있는 관광지로, 여름철 많은 사람들이 찾습니다.
#    - **오죽헌**: 조선 시대의 학자 율곡 이이가 태어난 곳으로, 역사적인 의미가 깊습니다.
#
# 이 외에도 대한민국에는 많은 매력적인 관광지가 있으니, 여행 계획을 세울 때 참고하시기 바랍니다.

# %% [markdown]
# ### 답변을 순차적으로 생성하여 보여주기

# %%
response = chain.stream({"question": user_input})
for token in response:
    print(token)
# Out:
# 대한
# 민국
# 에는
#  다양한
#  매
# 력
# 적인
#  관광
# 지가
#  많이
#  있습니다
# .
#  다음
# 은
#  그
#  중
#  일부
# 를
#  소개
# 합니다
# :
#
#
# 1
# .
#  **
# 서울
# **
#
#
#  -
#  **
# 경
# 복
# 궁
# **
# :
#  조
# 선
#  시대
# 의
#  대표
# 적인
#  궁
# 궐
# 로
# ,
#  한국
# 의
#  역사
# 와
#  문
# 화를
#  체
# 험
# 할
#  수
#  있는
#  곳
# 입니다
# .
#
#
#  -
#  **
# 남
# 산
# 타
# 워
# (N
# 서울
# 타
# 워
# )**
# :
#  서울
# 의
#  전
# 경
# 을
#  한
# 눈
# 에
#  볼
#  수
#  있는
#  전망
# 대
# 입니다
# .
#
#
#  -
#  **
# 명
# 동
# **
# :
#  쇼
# 핑
# 과
#  맛
# 집
# 이
#  많은
#  번
# 화
# 가
# 로
# ,
#  관광
# 객
# 들에게
#  인
# 기가
#  많
# 습니다
# .
#
#
#  -
#  **
# 인
# 사
# 동
# **
# :
#  전
# 통
# 과
#  현대
# 가
#  어
# 우
# 러
# 진
#  거리
# 로
# ,
#  전
# 통
#  공
# 예
# 품
# 과
#  갤
# 러
# 리
# ,
#  찻
# 집
#  등이
#  있습니다
# .
#
#
# 2
# .
#  **
# 부
# 산
# **
#
#
#  -
#  **
# 해
# 운
# 대
#  해
# 수
# 욕
# 장
# **
# :
#  대한민국
# 을
#  대표
# 하는
#  해
# 수
# 욕
# 장
# 으로
# ,
#  여
# 름
# 철
#  많은
#  관광
# 객
# 이
#  찾
# 습니다
# .
#
#
#  -
#  **
# 광
# 안
# 리
#  해
# 수
# 욕
# 장
# **
# :
#  광
# 안
# 대
# 교
# 의
#  야
# 경
# 이
#  아름
# 다운
#  해
# 변
# 입니다
# .
#
#
#  -
#  **
# 자
# 갈
# 치
#  시장
# **
# :
#  신
# 선
# 한
#  해
# 산
# 물을
#  맛
# 볼
#  수
#  있는
#  전
# 통
#  시장
# 입니다
# .
#
#
#  -
#  **
# 태
# 종
# 대
# **
# :
#  아름
# 다운
#  해
# 안
#  절
# 경
# 을
#  감
# 상
# 할
#  수
#  있는
#  자연
#  관광
# 지
# 입니다
# .
#
#
# 3
# .
#  **
# 경
# 주
# **
#
#
#  -
#  **
# 불
# 국
# 사
# **
# :
#  유
# 네
# 스
# 코
#  세계
# 문화
# 유
# 산
# 으로
#  지정
# 된
#  사
# 찰
# 로
# ,
#  석
# 굴
# 암
# 과
#  함께
#  유명
# 합니다
# .
#
#
#  -
#  **
# 첨
# 성
# 대
# **
# :
#  동
# 양
# 에서
#  가장
#  오래
# 된
#  천
# 문
# 대
# 입니다
# .
#
#
#  -
#  **
# 경
# 주
#  대
# 릉
# 원
# **
# :
#  신
# 라
#  시대
# 의
#  고
# 분
# 군
# 이
#  모
# 여
#  있는
#  곳
# 입니다
# .
#
#
# 4
# .
#  **
# 제
# 주
# 도
# **
#
#
#  -
#  **
# 한
# 라
# 산
# **
# :
#  대한민국
# 에서
#  가장
#  높은
#  산
# 으로
# ,
#  다양한
#  등
# 산
#  코
# 스
# 가
#  있습니다
# .
#
#
#  -
#  **
# 성
# 산
#  일
# 출
# 봉
# **
# :
#  일
# 출
# 이
#  아름
# 다운
#  곳
# 으로
#  유명
# 합니다
# .
#
#
#  -
#  **
# 천
# 지
# 연
#  폭
# 포
# **
# :
#  아름
# 다운
#  폭
# 포
# 와
#  주변
#  자연
#  경
# 관
# 이
#  인
# 상
# 적
# 입니다
# .
#
#
#  -
#  **
# 우
# 도
# **
# :
#  제주
# 도
#  동
# 쪽
# 에
#  위치
# 한
#  작은
#  섬
# 으로
# ,
#  아름
# 다운
#  해
# 변
# 과
#  자연
#  경
# 관
# 이
#  매
# 력
# 적
# 입니다
# .
#
#
# 5
# .
#  **
# 전
# 주
# **
#
#
#  -
#  **
# 전
# 주
#  한
# 옥
# 마
# 을
# **
# :
#  전
# 통
#  한
# 옥
# 이
#  모
# 여
#  있는
#  마
# 을
# 로
# ,
#  한국
# 의
#  전
# 통
#  문
# 화를
#  체
# 험
# 할
#  수
#  있습니다
# .
#
#
#  -
#  **
# 전
# 주
#  비
# 빔
# 밥
# **
# :
#  전
# 주의
#  대표
# 적인
#  음식
# 으로
# ,
#  다양한
#  재
# 료
# 가
#  어
# 우
# 러
# 진
#  맛
# 을
#  즐
# 길
#  수
#  있습니다
# .
#
#
# 이
#  외
# 에도
#  대한민국
# 에는
#  많은
#  아름
# 다운
#  자연
#  경
# 관
# 과
#  역사
# 적인
#  장소
# 들이
#  많
# 으
# 니
# ,
#  여행
#  계획
#  시
#  참고
# 하시
# 기
#  바랍니다
# .
